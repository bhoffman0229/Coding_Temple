# %% [markdown]
# ## **Pipeline**

# %%
import pandas as pd
import mongo as db

# %%
df = pd.read_csv('/home/user/Documents/coding_temple/week6/day3/MongoDB assignment/src/data/student-por.csv', sep=';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.columns = df.columns.str.lower().str.strip()
df
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# pstatus       0
# medu          0
# fedu          0
# mjob          0
# fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# dalc          0
# walc          0
# health        0
# absences      0
# g1            0
# g2            0
# g3            0
# dtype: int64

# %%
df.rename(columns={'traveltime':'travel_time','schoolsup':'school_sup','famsize':'fam_size','studytime':'study_time','freetime':'free_time','mjob':'mom_job','fjob':'dad_job'})
# Out:
#     school sex  age address fam_size pstatus  medu  fedu   mom_job   dad_job  \
# 0       GP   F   18       U      GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U      GT3       T     1     1   at_home     other
# 2       GP   F   15       U      LE3       T     1     1   at_home     other
# 3       GP   F   15       U      GT3       T     4     2    health  services
# 4       GP   F   16       U      GT3       T     3     3     other     other
# ..     ...  ..  ...     ...      ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R      GT3       T     2     3  services     other
# 645     MS   F   18       U      LE3       T     3     1   teacher  services
# 646     MS   F   18       U      GT3       T     1     1     other     other
# 647     MS   M   17       U      LE3       T     3     1  services  services
# 648     MS   M   18       R      LE3       T     3     2  services     other
#
# ...

# %%
df
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
USERNAME='bretthoffman44'
PASSWORD='Mv8bhAZ8ziadTXQ'
MONGO_URL='mongodb+srv://addsev:codingtemple@cluster0.ij5le.mongodb.net/?retryWrites=true&w=majority'

# %%
def uploadmongo():
    Username = USERNAME
    password = PASSWORD
    mongo_url = MONGO_URL
    client = pymongo.MongoClient(MONGO_URL)
    #Create a database
    db = client.database_names
    #Create a collection
    scores = db.df
    #Set dataframe index to the id column
    df.set_index('scores', inplace=True)
    for i in df.index:
            df.insert_one(df.loc[i].to_dict())

# %%
uploadmongo(df)
